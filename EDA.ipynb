# %% [markdown]
# Name- Abu Dawood Bin Hassan
# Email-abdul121rahaman121@gmail.com
# project- Exploratory data analysis on Apple app store

# %% [markdown]
# Exploratory Data analysis on Apple App Store
# 1.0 About Data
# Data: Apple AppStore
#
# Data Collection: This Data set is Collected From Kaggle.
#
# About Data: The dataset contains information about apps available on the Apple App Store.
#
# Dataset: https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps

# %% [markdown]
# 1.1 Task
# Our objective is to perform an in-depth Exploratory Data Analysis (EDA) on the provided dataset. This analysis will lay the foundation for essential Data Wrangling tasks, encompassing data cleansing and standardization procedures. Throughout the coding phase, we will meticulously document our insights and observations. Subsequently, we will compile a comprehensive summary and derive meaningful conclusions based on the patterns we uncover.

# %% [markdown]
# 2.0 Objectives
#
# Understand the Market: Analyze the distribution of apps across different categories and genres to understand the market demand and competition.
#
# Analyze User Ratings and Reviews: Investigate the relationship between user ratings, reviews, and other factors such as app size, price, and content rating to understand what drives user satisfaction.
#
# Identify Trends and Patterns: Explore trends and patterns in the data such as the release and update frequency of apps, changes in app size and price over time, and the impact of these factors on user ratings and reviews.
#
# Discover Opportunities: Identify gaps and opportunities in the market by analyzing the distribution of apps across different categories, genres, content ratings, and price points.

# %% [markdown]
# 3.0 Import Libraries
#
# In this section, we will import the following libraries for our data analysis:
#
# Pandas: For data manipulation, cleaning, and preprocessing.
#
# NumPy: For numerical computations and array operations.
#
# Seaborn: For creating attractive statistical visualizations.
#
# Matplotlib: For creating basic visualizations and graphs.
#
# Plotly: For interactive and dynamic visualizations.
#
# SciPy: For scientific and technical computing.
#
# Statsmodels: For estimating and interpreting statistical models

# %%
# 3.1 importing Libraries
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# loading the data set
df = pd.read_csv(r'C:\Users\91983\Desktop\Python_for_datascience\Data\appleAppData.csv')

# %%
# Display the first 5 rows of the DataFrame:
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
# get the data info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# After loading the data into a Pandas DataFrame,we can start by looking at descriptive statistic parameters for the dataset using describe().
#
# This will give us a summary of the central tendency, dispersion, and shape of the distribution of the dataset

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %%
# 3.4 To view Columns Names
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %%
# unique values:
df.nunique()
# Out:
# App_Id                     1230376
# App_Name                   1223510
# AppStore_Url               1230376
# Primary_Genre                   26
# Content_Rating                   5
# Size_Bytes                  255914
# Required_IOS_Version           260
# Released                    664824
# Updated                    1196053
# Version                      41270
# Price                           88
# Currency                         1
# Free                             2
# DeveloperId                 509285
# Developer                   505255
# Developer_Url               514106
# Developer_Website           403809
# Average_User_Rating          45073
# Reviews                      13668
# Current_Version_Score        45073
# Current_Version_Reviews      13668
# dtype: int64

# %%
# 3.5 View the shape of the data
print(f"The dataframe has {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# The dataframe has 1230376 rows and 21 columns

# %% [markdown]
# Observation:
# We have 7 numeric columns in the original dataset
# Column Size_bytes contains data in Bytes.
# App_Id has Most Unique numbers

# %%
# Check for missing values
df.isnull().sum()
# Out:
# App_Id                          0
# App_Name                        1
# AppStore_Url                    0
# Primary_Genre                   0
# Content_Rating                  0
# Size_Bytes                    224
# Required_IOS_Version            0
# Released                        3
# Updated                         0
# Version                         0
# Price                         490
# Currency                        0
# Free                            0
# DeveloperId                     0
# Developer                       0
# Developer_Url                1109
# Developer_Website          643988
# Average_User_Rating             0
# Reviews                         0
# Current_Version_Score           0
# Current_Version_Reviews         0
# dtype: int64

# %%
# By Cheking Null values we Can See Devoloper_website , Devoloper_url , Price , And Size_bytes have Null values

# %%
# Lets Create a heatmap to visualize missing values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap shows the distribution of missing values in dataset, with white cells indicating missing values and black cells indicating non-missing values.

# %%
df.isnull().sum().plot(kind='bar')
plt.title('Number of Missing Values by Column')
plt.show()

# %% [markdown]
# Observation :
# Dealing with the Null Values
#
# The columns having the highest percentage of null values are:
#
# Developer Website

# %% [markdown]
# 4.2 Dropping Attribute
# Based on its lack of relevance and the high number of NULL values associated with it, we have made the decision to drop this attribute from the dataset.

# %%
df.drop('Developer_Website', axis= , inplace=True)
df.info()
# Out:
#   Input In [18]
#     df.drop('Developer_Website', axis= , inplace=True)
#                                        ^
# SyntaxError: invalid syntax

# %%
# Lets Visualize Again
df.isnull().sum().plot(kind='bar')
plt.title('Number of Missing Values by Column')
plt.show()

# %%
# Lets Drop Devoloper URL too As we Dont Neend it According to Our Objective:
df.drop('Developer_Url', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# Observation:
# Price, Size_Bytes are important columns so it is good to fill the null values with mean value.

# %%
#filling mean value of Price column in the null places of that column
df['Price'] = df.Price.fillna(value=df['Price'].mean())
df['Size_Bytes'] = df.Size_Bytes.fillna(value=df['Size_Bytes'].mean())
##have a view of refreshed dataset again
df.isnull().sum().sort_values(ascending = False)
# Out:
# Released                   3
# App_Name                   1
# App_Id                     0
# Currency                   0
# Current_Version_Score      0
# Reviews                    0
# Average_User_Rating        0
# Developer                  0
# DeveloperId                0
# Free                       0
# Version                    0
# Price                      0
# Updated                    0
# Required_IOS_Version       0
# Size_Bytes                 0
# Content_Rating             0
# Primary_Genre              0
# AppStore_Url               0
# Current_Version_Reviews    0
# dtype: int64

# %% [markdown]
# We have some missing values in the Released and App_Name columns.
#
# There are several ways to handle missing values, including removing rows or columns with missing values, or imputing them with appropriate values such as the mean, median, or mode.
#
# For the Released column, which contains dates, one option is to remove rows with missing values using the dropna() function.

# %%
# Remove rows with missing values in the 'Released' column
df.dropna(subset=['Released'], inplace=True)
# Impute missing values in the 'App_Name' column with the mode
df['App_Name'].fillna(df['App_Name'].mode()[0], inplace=True)

##have a view of refreshed dataset again
df.isnull().sum().sort_values(ascending = False)
# Out:
# App_Id                     0
# Price                      0
# Current_Version_Score      0
# Reviews                    0
# Average_User_Rating        0
# Developer                  0
# DeveloperId                0
# Free                       0
# Currency                   0
# Version                    0
# App_Name                   0
# Updated                    0
# Released                   0
# Required_IOS_Version       0
# Size_Bytes                 0
# Content_Rating             0
# Primary_Genre              0
# AppStore_Url               0
# Current_Version_Reviews    0
# dtype: int64

# %%
# now the data set is sucessfully cleaned:

# %%
# its time to check dublicates value
# Check for duplicate rows
duplicates = df.duplicated()

# Count the number of duplicate rows
num_duplicates = duplicates.sum()

# Print the number of duplicate rows
print(f'Number of duplicate rows = {num_duplicates}')
# Out:
# Number of duplicate rows = 0

# %% [markdown]
# # looks like there are no dublicates:

# %% [markdown]
# Let’s start with Our objectives:

# %% [markdown]
#  Understand the market
# To understand the market demand and competition, we can analyze the distribution of apps across different categories and genres.

# %%
# Createing  a bar graph to visualize the distribution of apps by primary genre
sns.countplot(y='Primary_Genre', data=df, order=df['Primary_Genre'].value_counts().index)
plt.title('Number of Apps by Primary Genre')
plt.show()

# %% [markdown]
# Based on the bar graph, it appears that the Games genre has the highest number of apps in the Apple App Store. This suggests that there is a high demand for games among App Store users, and that the competition among game developers is likely to be intense. This information can be useful for app developers who are considering developing a game app, as it provides insight into the market demand and competition in this genre.

# %% [markdown]
# we can also analyze other aspects of the market such as the average price, size, and user rating of apps in each genre

# %%
import numpy as np
# Create a bar graph to visualize the average price of apps by primary genre
sns.barplot(x='Price', y='Primary_Genre', data=df, estimator=np.mean)
plt.title('Average Price of Apps by Primary Genre')
plt.show()

# %% [markdown]
# Observation: Average App Prices by Genre
# Upon analyzing the average prices of apps within different genres in the Apple App Store, the following observations are made:
#
# Graphics & Design" Genre: The "Graphics & Design" genre exhibits a notably high average app price. This suggests that apps within this genre tend to command higher prices in the market. This is likely due to the specialized nature of these apps, which may cater to professionals requiring advanced graphic design tools.
#
# Developer Tools" Genre: Similarly, the "Developer Tools" genre also displays a high average app price. This can be attributed to the fact that developer tools often target a niche market of software developers and professionals who are willing to pay premium prices for tools that enhance their productivity and capabilities.
#
# Market Segmentation: These findings emphasize the importance of understanding the target audience for each genre. In some genres, users may have higher price expectations, particularly if the apps offer specialized features or functionality.

# %%
# Create a histogram of user ratings
plt.figure(figsize=(8, 6))
sns.histplot(df['Average_User_Rating'], bins=20, kde=True)
plt.title('Distribution of User Ratings')
plt.xlabel('Average User Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#Calculate the correlation matrix & Visualize the correlation matrix as a heatmap
correlation_matrix = df[['Average_User_Rating', 'Size_Bytes', 'Price']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Observation: User Ratings
# Distribution and Correlation Analysis
#
# User Ratings Distribution:
# The histogram of user ratings reveals that the distribution of user ratings across apps in the dataset is slightly right-skewed. Most apps tend to have user ratings clustered around certain values, indicating polarization in user opinions.
#
# The majority of apps in the dataset fall within the range of user ratings between 3.5 and 5, indicating that many apps receive positive user feedback. However, there is also variability in user satisfaction, with some apps receiving lower ratings.
#
# Correlation Analysis:
# We conducted a correlation analysis to understand how user ratings ('Average_User_Rating') relate to other numerical variables such as app size ('Size_Bytes') and price ('Price').
#
# The correlation matrix and heatmap reveal the following insights:
#
# User ratings have a weak positive correlation with app size ('Size_Bytes'). Larger apps tend to, on average, receive slightly higher user ratings, although the correlation is not very strong.
# User ratings have a weak negative correlation with app price ('Price'). Lower-priced apps tend to, on average, receive slightly higher user ratings, although this correlation is also not very strong.
# Overall, this analysis suggests that user ratings vary across apps, with some receiving very high ratings and others lower ratings. While there is some correlation with app size and price, these factors alone do not strongly determine user ratings. User satisfaction with apps appears to be influenced by various factors beyond size and price, such as app functionality, user experience, and content quality.
#
# These insights are essential for making informed decisions related to app development, pricing strategies, and improving user satisfaction. Further analysis can help identify specific factors driving user ratings and reviews.

# %% [markdown]
# Identifying Trends and Patterns in the data
# This objective involves exploring various aspects of the dataset, such as the release and update frequency of apps, changes in app size and price over time, and the impact of these factors on user ratings and reviews..

# %% [markdown]
# Data Preparation
# First, let's ensure that the 'Released' and 'Updated' columns are in the correct datetime format. If they are not, we'll convert them.

# %%
# Convert 'Released' and 'Updated' columns to datetime format
df['Released'] = pd.to_datetime(df['Released'])
df['Updated'] = pd.to_datetime(df['Updated'])

# %% [markdown]
# Calculate Release and Update Frequency
# Next, we'll calculate the release and update frequency of apps. We can group the data by year and count the number of releases and updates in each year.

# %%
# Extract the release year and update year
df['Release_Year'] = df['Released'].dt.year
df['Update_Year'] = df['Updated'].dt.year

# %%
# Calculate the number of releases and updates per year
release_counts = df['Release_Year'].value_counts().sort_index()
update_counts = df['Update_Year'].value_counts().sort_index()

# %% [markdown]
# Visualize the Results
# Now, let's create visualizations to understand the trends in release and update frequency over the years.

# %%
import matplotlib.pyplot as plt

# Create a line plot for release frequency
plt.figure(figsize=(12, 6))
plt.plot(release_counts.index, release_counts.values, marker='o', label='Releases', color='blue')
plt.plot(update_counts.index, update_counts.values, marker='x', label='Updates', color='green')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Release and Update Frequency Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The graph shows the release and update frequency over time from 2008 to 2022.
# The number of releases and updates has generally increased over time, with a sharp spike in 2020.
# In 2020, the number of updates reached over 500,000, which is the highest point on the graph.
# In 2008, the number of releases was around 10,000, which is the lowest point on the graph.
# The blue line represents the number of releases, and the green line represents the number of updates.

# %% [markdown]
# The mobile app market has witnessed significant growth, with a substantial increase in both app releases and updates.
# The notable spike in updates in 2020 suggests a strong emphasis on improving existing apps, possibly driven by user feedback or industry trends.
# The data indicates potential seasonal or cyclical patterns in app releases and updates.
# Understanding these trends can inform app development strategies, with a focus on user satisfaction and timely updates.

# %% [markdown]
# Step 1: Analyze App Size Trends
# Let's begin by analyzing how the sizes of apps have evolved over the years. We'll create a visualization to show how the distribution of app sizes has changed.

# %%
# Create a scatterplot to visualize the distribution of app sizes over time
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Released', y='Size_Bytes', data=df, alpha=0.5)
plt.title('App Size Trends Over Time')
plt.xlabel('Year of Release')
plt.ylabel('App Size (Bytes)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The graph shows the relationship between the year of release and the app size in bytes from 2010 to 2021.
# The data points are represented by blue circles and are scattered, indicating that there is no clear trend in the relationship between the year of release and app size.
# There is a slight increase in app size over time, but there are also many outliers, indicating that other factors may be influencing app size.
# The range of app sizes is quite large, with some apps being very small and others being very large.
# Overall, the graph suggests that while there has been a slight increase in app size over time, there is no clear trend and other factors may be influencing app size.

# %% [markdown]
# Analyze App Price Trends
# Now, let's explore how the prices of apps have changed over the years. We'll create a visualization to show the distribution of app prices over time.

# %%
# Create a scatterplot to visualize the distribution of app prices over time
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Released', y='Price', data=df, alpha=0.5)
plt.title('App Price Trends Over Time')
plt.xlabel('Year of Release')
plt.ylabel('App Price (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The graph shows the relationship between the year of release and the app price in USD from 2010 to 2022.
# The data points are represented by blue circles and are scattered throughout the graph.
# There is a higher concentration of data points towards the bottom of the graph, indicating that most apps have lower prices.
# There are a few outliers towards the top of the graph, indicating that there are some apps with higher prices.
# Based on these observations, here are some insights for app developers:
#
# Most apps have lower prices, so if you want your app to be competitive in terms of price, you may want to consider pricing it lower.

# %% [markdown]
# Discover opportunities.
# Identify gaps and opportunities in the market by analyzing the distribution of apps across different categories, genres, content ratings, and price points. In this objective, we'll explore opportunities in the market by analyzing the distribution of apps across different categories, genres, content ratings, and price points.

# %% [markdown]
# Analyze Category Distribution
# Let's begin by analyzing the distribution of apps across different categories. We'll create a bar chart to visualize the number of apps in each category.

# %%
#Create a bar chart to visualize the distribution of apps by category
plt.figure(figsize=(12, 6))
sns.countplot(y='Primary_Genre', data=df, order=df['Primary_Genre'].value_counts().index)
plt.title('Number of Apps by Category')
plt.xlabel('Number of Apps')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# Analyze Content Rating Distribution
# Now, let's analyze the distribution of apps across different content ratings. We'll create a bar chart to visualize the number of apps in each content rating category.

# %%
# Create a bar chart to visualize the distribution of apps by content rating
plt.figure(figsize=(10, 6))
sns.countplot(y='Content_Rating', data=df, order=df['Content_Rating'].value_counts().index)
plt.title('Number of Apps by Content Rating')
plt.xlabel('Number of Apps')
plt.ylabel('Content Rating')
plt.show()

# %% [markdown]
# Analyze Price Points
# Finally, let's analyze the distribution of apps based on price points. We'll create a histogram to visualize the distribution of app prices.

# %%
# Create a histogram to visualize the distribution of app prices
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=20, kde=True)
plt.title('Distribution of App Prices')
plt.xlabel('Price (USD)')
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# Observation:
# Category Distribution: The bar chart showing the distribution of apps by category indicates that some categories have a significantly higher number of apps than others. The categories with the highest number of apps are Games, followed by Education and Business. The category with the lowest number of apps is Magazines & Newspapers. This suggests that there may be opportunities for game developers to target less crowded categories, where there may be less competition and more potential for growth. On the other hand, it may also make sense for game developers to target categories with high demand, where there is a large market for apps.
#
# Content Rating Distribution: The content rating distribution chart shows that the content rating with the highest number of apps is "4+", while the content rating with the lowest number of apps is "Not yet rated". This suggests that there may be gaps in the market for games with specific content ratings, such as "17+" or "Not yet rated". Game developers may want to consider targeting these less crowded content ratings to differentiate their game from others in the market.
#
# Price Points: The histogram illustrating the distribution of app prices shows that the most common price point for apps is 0 USD. However, without further data, it is not possible to determine whether there are clusters of apps at specific price ranges or if there is a correlation between app price and user ratings or downloads.
